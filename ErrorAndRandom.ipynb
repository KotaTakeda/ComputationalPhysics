# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import random
import time

# %%
N = 60
eps = 1.0

for i in range(N):
    eps /= 2
    one_Plus_eps = 1.0 + eps
#     if i%10==0:
    print(i, ': eps = ',eps, ', one_Plus_eps = ', one_Plus_eps)
# Out:
# 0 : eps =  0.5 , one_Plus_eps =  1.5
# 1 : eps =  0.25 , one_Plus_eps =  1.25
# 2 : eps =  0.125 , one_Plus_eps =  1.125
# 3 : eps =  0.0625 , one_Plus_eps =  1.0625
# 4 : eps =  0.03125 , one_Plus_eps =  1.03125
# 5 : eps =  0.015625 , one_Plus_eps =  1.015625
# 6 : eps =  0.0078125 , one_Plus_eps =  1.0078125
# 7 : eps =  0.00390625 , one_Plus_eps =  1.00390625
# 8 : eps =  0.001953125 , one_Plus_eps =  1.001953125
# 9 : eps =  0.0009765625 , one_Plus_eps =  1.0009765625
# 10 : eps =  0.00048828125 , one_Plus_eps =  1.00048828125
# 11 : eps =  0.000244140625 , one_Plus_eps =  1.000244140625
# 12 : eps =  0.0001220703125 , one_Plus_eps =  1.0001220703125
# 13 : eps =  6.103515625e-05 , one_Plus_eps =  1.00006103515625
# 14 : eps =  3.0517578125e-05 , one_Plus_eps =  1.000030517578125
# 15 : eps =  1.52587890625e-05 , one_Plus_eps =  1.0000152587890625
# 16 : eps =  7.62939453125e-06 , one_Plus_eps =  1.0000076293945312
# 17 : eps =  3.814697265625e-06 , one_Plus_eps =  1.0000038146972656
# 18 : eps =  1.9073486328125e-06 , one_Plus_eps =  1.0000019073486328
# 19 : eps =  9.5367431640625e-07 , one_Plus_eps =  1.0000009536743164
# 20 : eps =  4.76837158203125e-07 , one_Plus_eps =  1.0000004768371582
# 21 : eps =  2.384185791015625e-07 , one_Plus_eps =  1.000000238418579
# 22 : eps =  1.1920928955078125e-07 , one_Plus_eps =  1.0000001192092896
# 23 : eps =  5.960464477539063e-08 , one_Plus_eps =  1.0000000596046448
# 24 : eps =  2.9802322387695312e-08 , one_Plus_eps =  1.0000000298023224
# 25 : eps =  1.4901161193847656e-08 , one_Plus_eps =  1.0000000149011612
# 26 : eps =  7.450580596923828e-09 , one_Plus_eps =  1.0000000074505806
# 27 : eps =  3.725290298461914e-09 , one_Plus_eps =  1.0000000037252903
# 28 : eps =  1.862645149230957e-09 , one_Plus_eps =  1.0000000018626451
# 29 : eps =  9.313225746154785e-10 , one_Plus_eps =  1.0000000009313226
# 30 : eps =  4.656612873077393e-10 , one_Plus_eps =  1.0000000004656613
# 31 : eps =  2.3283064365386963e-10 , one_Plus_eps =  1.0000000002328306
# 32 : eps =  1.1641532182693481e-10 , one_Plus_eps =  1.0000000001164153
# 33 : eps =  5.820766091346741e-11 , one_Plus_eps =  1.0000000000582077
# 34 : eps =  2.9103830456733704e-11 , one_Plus_eps =  1.0000000000291038
# 35 : eps =  1.4551915228366852e-11 , one_Plus_eps =  1.000000000014552
# 36 : eps =  7.275957614183426e-12 , one_Plus_eps =  1.000000000007276
# 37 : eps =  3.637978807091713e-12 , one_Plus_eps =  1.000000000003638
# 38 : eps =  1.8189894035458565e-12 , one_Plus_eps =  1.000000000001819
# 39 : eps =  9.094947017729282e-13 , one_Plus_eps =  1.0000000000009095
# 40 : eps =  4.547473508864641e-13 , one_Plus_eps =  1.0000000000004547
# 41 : eps =  2.2737367544323206e-13 , one_Plus_eps =  1.0000000000002274
# 42 : eps =  1.1368683772161603e-13 , one_Plus_eps =  1.0000000000001137
# 43 : eps =  5.684341886080802e-14 , one_Plus_eps =  1.0000000000000568
# 44 : eps =  2.842170943040401e-14 , one_Plus_eps =  1.0000000000000284
# 45 : eps =  1.4210854715202004e-14 , one_Plus_eps =  1.0000000000000142
# 46 : eps =  7.105427357601002e-15 , one_Plus_eps =  1.000000000000007
# 47 : eps =  3.552713678800501e-15 , one_Plus_eps =  1.0000000000000036
# 48 : eps =  1.7763568394002505e-15 , one_Plus_eps =  1.0000000000000018
# 49 : eps =  8.881784197001252e-16 , one_Plus_eps =  1.0000000000000009
# 50 : eps =  4.440892098500626e-16 , one_Plus_eps =  1.0000000000000004
# 51 : eps =  2.220446049250313e-16 , one_Plus_eps =  1.0000000000000002
# 52 : eps =  1.1102230246251565e-16 , one_Plus_eps =  1.0
# 53 : eps =  5.551115123125783e-17 , one_Plus_eps =  1.0
# 54 : eps =  2.7755575615628914e-17 , one_Plus_eps =  1.0
# 55 : eps =  1.3877787807814457e-17 , one_Plus_eps =  1.0
# 56 : eps =  6.938893903907228e-18 , one_Plus_eps =  1.0
# 57 : eps =  3.469446951953614e-18 , one_Plus_eps =  1.0
# 58 : eps =  1.734723475976807e-18 , one_Plus_eps =  1.0
# 59 : eps =  8.673617379884035e-19 , one_Plus_eps =  1.0

# %% [markdown]
# ## 乱数

# %% [markdown]
# ### 線形合同法
# 失敗例

# %%
randoms = []
N = 260
a = 57; c = 1; M =256; r = 10
for i in range(N):
    r = (a*r + c)%M
    if r in randoms:
        print(i)
        
    randoms.append(r)
print(randoms)
# Out:
# 256
# 257
# 258
# 259
# [59, 36, 5, 30, 175, 248, 57, 178, 163, 76, 237, 198, 23, 32, 33, 90, 11, 116, 213, 110, 127, 72, 9, 2, 115, 156, 189, 22, 231, 112, 241, 170, 219, 196, 165, 190, 79, 152, 217, 82, 67, 236, 141, 102, 183, 192, 193, 250, 171, 20, 117, 14, 31, 232, 169, 162, 19, 60, 93, 182, 135, 16, 145, 74, 123, 100, 69, 94, 239, 56, 121, 242, 227, 140, 45, 6, 87, 96, 97, 154, 75, 180, 21, 174, 191, 136, 73, 66, 179, 220, 253, 86, 39, 176, 49, 234, 27, 4, 229, 254, 143, 216, 25, 146, 131, 44, 205, 166, 247, 0, 1, 58, 235, 84, 181, 78, 95, 40, 233, 226, 83, 124, 157, 246, 199, 80, 209, 138, 187, 164, 133, 158, 47, 120, 185, 50, 35, 204, 109, 70, 151, 160, 161, 218, 139, 244, 85, 238, 255, 200, 137, 130, 243, 28, 61, 150, 103, 240, 113, 42, 91, 68, 37, 62, 207, 24, 89, 210, 195, 108, 13, 230, 55, 64, 65, 122, 43, 148, 245, 142, 159, 104, 41, 34, 147, 188, 221, 54, 7, 144, 17, 202, 251, 228, 197, 222, 111, 184, 249, 114, 99, 12, 173, 134, 215, 224, 225, 26, 203, 52, 149, 46, 63, 8, 201, 194, 51, 92, 125, 214, 167, 48, 177, 106, 155, 132, 101, 126, 15, 88, 153, 18, 3, 172, 77, 38, 119, 128, 129, 186, 107, 212, 53, 206, 223, 168, 105, 98, 211, 252, 29, 118, 71, 208, 81, 10, 59, 36, 5, 30]

# %%
_ = plt.plot(randoms)

# %% [markdown]
# 続いて発生する２つの組みをプロット

# %%
x = []
y = []
for i in range(len(randoms)//2):
    x.append(randoms[2*i])
    y.append(randoms[2*i+1])
_ = plt.scatter(x,y)

# %%
true_randoms = []
for i in range(260):
    true_randoms.append(random.randint(0,100))
_ = plt.plot(true_randoms)

# %%
x_ = []
y_ = []
for i in range(len(true_randoms)//2):
    x_.append(true_randoms[2*i])
    y_.append(true_randoms[2*i+1])
_ = plt.scatter(x_,y_)

# %%
fig = plt.figure()
op = []
K = 5
N = 1000
x_ = []; y_ = []
x = 0.; y= 0.
for k in range(K):
    random.seed(k)
    for i in range(N):
        x_.append(x); y_.append(y)
        dx = (random.random() - 0.5)*2; dy = (random.random() - 0.5)*2
        l = (dx**2 + dy**2)**(0.5)
        dx /= l; dy /= l
        x +=  dx; y += dy
    op = 321 + k
    ax = fig.add_subplot(op)
    _ = ax.plot(x_,y_,color="r")

# %% [markdown]
# ### ランダムウォーク
# #### 平均移動距離と$\sqrt{N}$の関係

# %%
fig = plt.figure()
op = []

ks = []
dists = []

x_ = []; y_ = []
x = 0.; y= 0.
R2k = 0.; R2 = 0.
for m in range(5):
    N = 10**m
    K = int(N**0.5)
    ks.append(K)
    R2 = 0.
    for k in range(K):
        random.seed(k)
        R2k = 0.
        for i in range(N):
            x_.append(x); y_.append(y)
            dx = (random.random() - 0.5)*2; dy = (random.random() - 0.5)*2
            l = (dx**2 + dy**2)**(0.5)
            dx /= l; dy /= l
            x +=  dx; y += dy
            
            R2k += dx**2 + dy**2
            
        R2 += R2k
        
    R2 /= K
    
    dists.append(R2**0.5)
    print(R2**0.5)
    
fig  = plt.figure()
ax = fig.add_subplot()
ax.set_xlabel("sqrt'(N)")
ax.set_ylabel("R")
_ = plt.plot(ks,dists,color="r")
# Out:
# 1.0
# 3.1622776601683795
# 10.0
# 31.622776601683793
# 100.0

# %% [markdown]
# ### 放射線崩壊
# 指数分布の再現
# $N = c e^{-\lambda t}$となっているか？

# %%
lambda1 = 0.005
max = 800; time_max = 2000; seed  = 68111
number = nloop = max
atoms = []
for t in range(time_max + 1):
#     print(f"time{t}")
    for atom in range(1, number + 1):
        decay = random.random()
        if (decay < lambda1):
            nloop -= 1
#             print(f"atom{atom}崩壊")
        number = nloop
    atoms.append(number)
#     time.sleep(0.5)

fig, ax = plt.subplots()
ax.set_xlabel("time")
ax.set_ylabel("number of atoms")
_ = ax.plot(atoms)
